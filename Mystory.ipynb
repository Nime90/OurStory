# %%
print("let's start")

# %%
import pandas as pd

# %%
data= pd.read_excel('Metric10_data.xlsx')

# %%
data
# Out:
#      customer_id  converted  customer_segment  gender   age  \
# 0          15001          0                13    male  22.0
# 1          15002          1                11  female  38.0
# 2          15003          1                13  female  26.0
# 3          15004          1                11  female  35.0
# 4          15005          0                13    male  35.0
# ..           ...        ...               ...     ...   ...
# 886        15887          0                12    male  27.0
# 887        15888          1                11  female  19.0
# 888        15889          0                13  female   NaN
# 889        15890          1                11    male  26.0
# 890        15891          0                13    male  32.0
#
#      related_customers  family_size  initial_fee_level  \
# 0                    1            0              14.50
# 1                    1            0         1425666.00
# 2                    0            0              15.85
# ...

# %%
display(data.head(2))
data.tail(2)
# Out:
#    customer_id  converted  customer_segment  gender   age  related_customers  \
# 0        15001          0                13    male  22.0                  1
# 1        15002          1                11  female  38.0                  1
#
#    family_size  initial_fee_level  \
# 0            0               14.5
# 1            0          1425666.0
#
#                                    credit_account_id    branch
# 0  9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...  Helsinki
# 1  afa2dc179e46e8456ffff9016f91396e9c6adf1fe20d17...   Tampere
#      customer_id  converted  customer_segment gender   age  related_customers  \
# 889        15890          1                11   male  26.0                  0
# 890        15891          0                13   male  32.0                  0
#
#      family_size  initial_fee_level  \
# 889            0               60.0
# 890            0               15.5
#
#                                      credit_account_id   branch
# ...

# %%
data.age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
data[data['age']<1]
# Out:
#      customer_id  converted  customer_segment  gender   age  \
# 78         15079          1                12    male  0.83
# 305        15306          1                11    male  0.92
# 469        15470          1                13  female  0.75
# 644        15645          1                13  female  0.75
# 755        15756          1                12    male  0.67
# 803        15804          1                13    male  0.42
# 831        15832          1                12    male  0.83
#
#      related_customers  family_size  initial_fee_level  \
# 78                   0            2               58.0
# 305                  1            2              303.1
# 469                  2            1           385166.0
# 644                  2            1           385166.0
# 755                  1            1               29.0
# 803                  0            1           170334.0
# 831                  1            1               37.5
#
# ...

# %%
display(data.branch.unique())
data.gender.unique()
# Out:
# array(['Helsinki', 'Tampere', 'Turku', nan], dtype=object)
# array(['male', 'female'], dtype=object)

# %%
#converting gender and branch into a numerical value: it will be usefull further down in the analysis
female=[]
for g in data.gender:
    if g=='female': female.append(1)
    else: female.append(0)
data['female']=female

branch_n=[]
for b in data.branch:
    if b=='Helsinki': branch_n.append(0)
    elif b=='Tampere': branch_n.append(1)
    elif b=='Turku': branch_n.append(2)
    else: branch_n.append(None)

data['branch_n']=branch_n

# %%
data['female']=female

# %%
data
# Out:
#      customer_id  converted  customer_segment  gender   age  \
# 0          15001          0                13    male  22.0
# 1          15002          1                11  female  38.0
# 2          15003          1                13  female  26.0
# 3          15004          1                11  female  35.0
# 4          15005          0                13    male  35.0
# ..           ...        ...               ...     ...   ...
# 886        15887          0                12    male  27.0
# 887        15888          1                11  female  19.0
# 888        15889          0                13  female   NaN
# 889        15890          1                11    male  26.0
# 890        15891          0                13    male  32.0
#
#      related_customers  family_size  initial_fee_level  \
# 0                    1            0              14.50
# 1                    1            0         1425666.00
# 2                    0            0              15.85
# ...

# %%
#checking info on the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        891 non-null    int64
#  1   converted          891 non-null    int64
#  2   customer_segment   891 non-null    int64
#  3   gender             891 non-null    object
#  4   age                714 non-null    float64
#  5   related_customers  891 non-null    int64
#  6   family_size        891 non-null    int64
#  7   initial_fee_level  891 non-null    float64
#  8   credit_account_id  891 non-null    object
#  9   branch             889 non-null    object
#  10  female             891 non-null    int64
#  11  branch_n           889 non-null    float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#         customer_id   converted  customer_segment         age  \
# count    891.000000  891.000000        891.000000  714.000000
# mean   15446.000000    0.383838         12.308642   29.699118
# std      257.353842    0.486592          0.836071   14.526497
# min    15001.000000    0.000000         11.000000    0.420000
# 25%    15223.500000    0.000000         12.000000   20.125000
# 50%    15446.000000    0.000000         13.000000   28.000000
# 75%    15668.500000    1.000000         13.000000   38.000000
# max    15891.000000    1.000000         13.000000   80.000000
#
#        related_customers  family_size  initial_fee_level      female  \
# count         891.000000   891.000000       8.910000e+02  891.000000
# mean            0.523008     0.381594       2.012785e+05    0.352413
# std             1.102743     0.806057       7.683462e+05    0.477990
# min             0.000000     0.000000       0.000000e+00    0.000000
# ...

# %%
#making a deepdown on the variable "age": checking data for "too young" customers
data_age=data[data['age']<13]
data_age.groupby('age')['customer_id'].count()
#sum(data_age.groupby('age')['customer_id'].count())
# Out:
# age
# 0.42      1
# 0.67      1
# 0.75      2
# 0.83      2
# 0.92      1
# 1.00      7
# 2.00     10
# 3.00      6
# 4.00     10
# 5.00      4
# 6.00      3
# 7.00      3
# 8.00      4
# 9.00      8
# 10.00     2
# 11.00     4
# 12.00     1
# Name: customer_id, dtype: int64

# %%
data.initial_fee_level.unique()[:10]
# Out:
# array([1.450000e+01, 1.425666e+06, 1.585000e+01, 1.062000e+02,
#        1.610000e+01, 1.691660e+05, 1.037250e+05, 4.215000e+01,
#        2.226660e+05, 6.014160e+05])

# %%
data.isnull().sum()
# Out:
# customer_id            0
# converted              0
# customer_segment       0
# gender                 0
# age                  177
# related_customers      0
# family_size            0
# initial_fee_level      0
# credit_account_id      0
# branch                 2
# female                 0
# branch_n               2
# dtype: int64

# %%
data=data.dropna()
age_r=[int(a) for a in data.age]

age_r=[]
for a in data.age:
    age_r.append(int(a))

# %%
data['age_r']=age_r
# Out:
# /var/folders/fv/p0rx_xkn0kb849n9w9m2zkhr0000gp/T/ipykernel_25132/2949634910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['age_r']=age_r

# %%
data.columns
# Out:
# Index(['customer_id', 'converted', 'customer_segment', 'gender', 'age',
#        'related_customers', 'family_size', 'initial_fee_level',
#        'credit_account_id', 'branch', 'female', 'branch_n', 'age_r'],
#       dtype='object')

# %%
data.groupby('family_size')['customer_id'].count()
# Out:
# family_size
# 0    519
# 1    110
# 2     68
# 3      5
# 4      4
# 5      5
# 6      1
# Name: customer_id, dtype: int64

# %%
#Plot all the variables against each other
import seaborn as sns
sns.set_style("whitegrid")
sns.pairplot(data)
# Out:
# Matplotlib is building the font cache; this may take a moment.
